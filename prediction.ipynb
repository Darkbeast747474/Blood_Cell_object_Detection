# %% [markdown]
# # Model Inference on a Sample Image

# %%
from IPython.display import Image
Image("dataset/images/test/BloodImage_00011.jpg")

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train/weights/best.pt") #Loading Pretrained Model
results = model.predict(source="dataset/images/test/BloodImage_00011.jpg",save=True) #Predicting the image
Image("runs/detect/predict/BloodImage_00011.jpg") #Predicted Image
# Out:
# image 1/1 /home/rex/CLG/Workbench/course_work/Deep_learning/Object_detection/dataset/images/test/BloodImage_00011.jpg: 480x640 1 WBC, 25 RBCs, 1 Platelets, 48.4ms
# Speed: 3.9ms preprocess, 48.4ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
# Results saved to runs/detect/predict2

# %%
Image("BCCD/Preprocessed_imgs/BloodImage_00011.jpg") #Original Annoted Image
